# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
graph = df.loan_amnt.hist(bins=50)
graph.set_title("loan frequency")
graph.set_xlabel("loan amount")
graph.set_ylabel("number of loans")
# Out:
# Text(0,0.5,'number of loans')

# %%
df = pd.read_csv("loan.csv", usecols=["loan_amnt", "int_rate", "loan_status" ])

# %%
df.columns
# Out:
# Index(['loan_amnt', 'int_rate', 'loan_status'], dtype='object')

# %%
df.head()
# Out:
#    loan_amnt  int_rate loan_status
# 0       2500     13.56     Current
# 1      30000     18.94     Current
# 2       5000     17.97     Current
# 3       4000     18.94     Current
# 4      30000     16.14     Current

# %%
df.loan_amnt.unique()
# Out:
# array([ 2500, 30000,  5000, ...,   925,   550,   850])

# %%
graph = df.loan_amnt.hist(bins=50)
graph.set_title("loan frequency")
graph.set_xlabel("loan amount")
graph.set_ylabel("number of loans")
# Out:
# Text(0,0.5,'number of loans')

# %%
graph = df.int_rate.hist(bins=100)
graph.set_title("loan frequency")
graph.set_xlabel("loan amount")
graph.set_ylabel("number of loans")
# Out:
# Text(0,0.5,'number of loans')
